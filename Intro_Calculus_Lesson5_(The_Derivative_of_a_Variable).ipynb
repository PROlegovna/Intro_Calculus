# %%
Введение в математический анализ
Урок 5
Производная функции одной переменной. Часть 1
Практическое задание

# %%
1.Найти производную функции:
 y=1/x+2x^2−5x^3+√x−^3√x+3√x 

y’ = (x^-1)’ + (2*x^-2)’ - (5x^-3)+ (x^1/2)’ - (x^1/3)’ + (3*x^-1/2)’ =
-1*x^-2 + 2*(-2)*x^-3 - 5 * (-3) * x^-4 + 1/2*x^-1/2 - 1/3*x^-2/3 + -1/2* x^-3/2 = 
-1/x^2 - 4/x^3 + 15/x^4 + 1/2√x - 1/3x^2/3 - 3/2x^3/2 

2.Найти производную функции:
y=x⋅√(1+x^2)

y’ = (x* √1+x^2)’ = x’*(√1+x^2) + x(√1+x^2)’ = 
1*(√1+x^2) + x*(1+x^2)’ * (√1+x^2)’ = (√1+x^2) + (2x^2 / 2√1-x^2) = 
(√1+x^2) + (x^2 / √1+x^2) = (2x^2 + 1) / (√1+x^2)

3.Найти производную функции:
y=2x/(1−x^2)

y’ = (2x / (1-x^2))’ = ((2x)’*(1-x^2) - 2x * (1-x^2)’) / (1-x^2)^2 = 
((2-2x^2) +4x^2)/ (1-x^2)^2 = (2x^2 + 2)/(1-x^2)^2 = (2(1+x^2)) / (1-x^2)(1+x^2) = 
2/(1-x^2)

4.Найти производную функции:
y=√(x+√(x+√x))

y’ = (√(x + √(x + √(x))))’ = ((x + (x + x^1/2)^1/2)^1/2)’ = 
1/2√(x + √(x + √(x))) * ((x + (x +x^1/2)^1/2))’ = 
1/2√(x + √(x + √(x))) * (1+1/2√(x+√(x)) * (x+x^1/2)’) = 
1/2√(x + √(x + √(x))) * (1+1/2√(x+√(x)) * (1 + 1/2√x)) = 
1/2√(x + √(x + √(x))) * (1+1/2√(x+√(x)) + 1/4√(x +√(x))*√x) = 
1/2√(x + √(x + √(x))) + 1/2√(x + √(x + √(x))) * 1/2√(x + √(x)) + 1/2√(x + √(x + √(x))) * 1/4(√(x + √(x)))*√(x) = 
1/2√(x + √(x + √(x))) + 1/(4√(x + √(x + √(x)))*√(x+√(x))) + 1/(8(√(x + √(x + √(x))) * √(x + √(x)))*√(x)) = 
(4√x + (√x+√(x)) + 2√x + 1) / (8(√(x + √(x + √(x))) * √(x + √(x)))*√(x))

5.Найти производную функции:
y=ln(x+√(x^2+1))

y = ln(x+√(x^2+1))’ = 1/(x + √(x^2+1)) * (x/√(x^2+1) + 1) = 
x+√(x^2+1) / (x^2 + x√(x^2+1) + 1)


6.Найти производную функции:
y= x*ln(x+√(x^2+1))−√(x^2+1)

y= x*ln(x+√(x^2+1))−√(x^2+1) = 
- √(1 + x^2) + x*ln(x+√(1+x^2)) = 
x*ln(x+√(1+x^2)) - √(1 + x^2)/(2√(1+x^2)) = 
x*ln(x+√(1+x^2)) - (1+x^2) 1/(2√(1+x^2)) = 
x*ln(x+√(1+x^2)) - (x^2 + 0) /(2√(1+x^2)) = 
- x^2 /(2√(1+x^2)) + x*ln(x+√(1+x^2)) =
x*ln(x+√(1+x^2)) - (2x) (1/(2√(1+x^2))) = 
- x/√(1+x^2) + x*ln(x+√(1+x^2)) = 
- x/√(1+x^2) + (ln(x+√(1+x^2))(x) + (x*ln(x+√(1+x^2)))) =
- x/√(1+x^2) + ln(x+√(1+x^2))(x) + x*ln(x+√(1+x^2)) =
- x/√(1+x^2) + x*ln(x+√(1+x^2)) + 1*ln(x+√(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x+√(1+x^2))/(x+√(1+x2))(x) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x+√(1+x^2)) ((x)/(x+√(1+x^2))) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + ((x√(1+x^2) +1)/(x+√(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + (((1+x^2)/2√(1+x^2)) / (x + √(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + (((x^2 + 0)/2√(1+x^2)) / (x + √(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + (((x^2)/2√(1+x^2)) / (x + √(1+x^2)) = 
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + 2x(((1)/2√(1+x^2)) / (x + √(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + (((x)/√(1+x^2)) / (x + √(1+x^2)) =
- x/√(1+x^2) + ln(x+√(1+x^2)) + (x(1 + (((x)/√(1+x^2)) / (x + √(1+x^2)) = 
ln(x+√(1+x^2))

7.Найти производную функции:
y=arcsin(sinx)

y=arcsin(sinx) = sin^-1(sin(x)) = (sin(x))/√(1-sin^2(x)) =
cos(x)(x)(1/√(1-sin^2(x))) = 1((cos(x))/√(1-sin^2(x))) = 
√cos2(x)sec(x)

# %%
## Вычислить приближенное значение:
# sin(1^0)=sin(π/180)


import numpy as np
cos = 1
f = 0
for i in range (0,20):
    x = (np.pi*i)/180 - f
    y = np.sin(x) + cos*f
    cos = np.cos(x) - np.sin(x)*f
    f = (np.pi*(i-1))/180
    print(f'degree:{i} sin:{y}')
# Out:
# degree:0 sin:0.0
# degree:1 sin:0.017446204182557674
# degree:2 sin:0.03489949670250097
# degree:3 sin:0.05234215714821329
# degree:4 sin:0.06976355560465089
# degree:5 sin:0.08716369207181374
# degree:6 sin:0.10454256654970183
# degree:7 sin:0.1219001790383152
# degree:8 sin:0.1392365295376538
# degree:9 sin:0.1565516180477177
# degree:10 sin:0.1738454445685068
# degree:11 sin:0.19111800910002125
# degree:12 sin:0.20836931164226086
# degree:13 sin:0.2255993521952258
# degree:14 sin:0.242808130758916
# degree:15 sin:0.25999564733333136
# degree:16 sin:0.2771619019184721
# degree:17 sin:0.2943068945143381
# degree:18 sin:0.3114306251209293
# degree:19 sin:0.3285330937382457

# %%
## Написать на python алгоритм, по вычислению значений sin(x) для х∈[0,300]


import numpy as np
cos = 1
f = 0
for i in range (0,20):
    x = (np.pi)/180
    y = np.sin(0) + cos*f
    cos = np.cos(0) - y*f
    f = f + x
    print(f'degree:{i} sin:{y}')
# Out:
# degree:0 sin:0.0
# degree:1 sin:0.017453292519943295
# degree:2 sin:0.03489595188601818
# degree:3 sin:0.05229609807088277
# degree:4 sin:0.069622006450262
# degree:5 sin:0.08684230108041142
# degree:6 sin:0.10392614478915611
# degree:7 sin:0.12084342364849285
# degree:8 sin:0.1375649234925866
# degree:9 sin:0.15406249629207197
# degree:10 sin:0.17030921438985783
# degree:11 sin:0.18627951083950886
# degree:12 sin:0.20194930435777944
# degree:13 sin:0.21729610769995758
# degree:14 sin:0.23229911858158556
# degree:15 sin:0.24693929259372907
# degree:16 sin:0.2611993978821671
# degree:17 sin:0.2750640516749396
# degree:18 sin:0.2885197390396062
# degree:19 sin:0.30155481452431016
