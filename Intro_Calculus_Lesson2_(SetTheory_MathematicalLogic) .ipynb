# %%
Введение в математический анализ
Урок 2
Теория множеств. Математическая логика.
Практическое задание

# %%
1. Представьте в виде несократимой рациональной дроби:

а) 0.(216)
b = 0.(216)
1000b = 216.(216)
1000b = 216 + 0.(216)
1000b = 216 + b
999b = 216
b = 216/999
b = 8/37

б) 1.0(01)
c = 1.0(01)
10c = 10.(01)
10c = 10 + 0.(01)

b = 0.(01)
100b = 01.(01)
100b = 1 + 0.(01)
99b = 1
b = 1/99

10c = 10 + 1/99
10c = 991/99
c = 991/990

# %%
3. Проверьте любым способ, является ли данные логические формулы тавтологией:
a)(A∨B)→(B∨A¯) не тавтология
б)A→(A∨(B¯∧A)) тавтология

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import HTML, display
from tabulate import tabulate

tabledata = [
    ['A', 0, 1, 0, 1],
    ['B', 0, 0, 1, 1],
    ['A∨B', 0, 1, 1, 1],
    ['B∨A¯', 1, 0, 1, 1],
    ['(A∨B)→(B∨A¯)', 1, 0, 1, 1]]
display (HTML (tabulate(tabledata, tablefmt = 'html')))
# Out:
# <table>
# <tbody>
# <tr><td>A           </td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td></tr>
# <tr><td>B           </td><td style="text-align: right;">0</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# <tr><td>A∨B         </td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# <tr><td>B∨A¯        </td><td style="text-align: right;">1</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# <tr><td>(A∨B)→(B∨A¯)</td><td style="text-align: right;">1</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# </tbody>
# </table>

# %%
tabledata = [
    ['A', 0, 1, 0, 1],
    ['B', 0, 0, 1, 1],
    ['B¯∧A', 0, 0, 0, 1],
    ['A∨(B¯∧A)', 0, 1, 0, 1],
    ['A→(A∨(B¯∧A))', 1, 1, 1, 1]]
display (HTML (tabulate(tabledata, tablefmt = 'html')))
# Out:
# <table>
# <tbody>
# <tr><td>A           </td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td></tr>
# <tr><td>B           </td><td style="text-align: right;">0</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# <tr><td>B¯∧A        </td><td style="text-align: right;">0</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td></tr>
# <tr><td>A∨(B¯∧A)    </td><td style="text-align: right;">0</td><td style="text-align: right;">1</td><td style="text-align: right;">0</td><td style="text-align: right;">1</td></tr>
# <tr><td>A→(A∨(B¯∧A))</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td></tr>
# </tbody>
# </table>

# %%
4. Сформулируйте словесно высказывания:

a)(A¯∨B)→C¯
Если сегодня не светит солнце или сегодня сыро, то я не поеду на дачу
б)C→(A∨B¯)
Если я поеду на дачу, то сегодня светит солнце или не сыро

A: сегодня светит солнце;
B: сегодня сыро;
C: я поеду на дачу.

# %%
5. Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:

a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
∀ курсе ∀ факультета ∃ студенты сдающие ∀ экзамен на «отлично»
∃ курсе ∃ факультета ∀ студенты сдающие ∃ экзамен на «отлично»
Есть курс факультета, на котором каждый студент сдаёт один экзамен на «отлично»

б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
∀ самолёте на рейсе Вашингтон-Москва ∃ сотрудник силовых органов, ∀ пуговице одежды которого ∃ микрофон.
∃ самолёте на рейсе Вашингтон-Москва ∀ сотрудник силовых органов, ∃ пуговице одежды которого ∀ микрофон.
Есть самолёт на рейсе Вашингтон-Москва, на котором у каждого сотрудника силовых органов в пуговице одежды вмонтирован любой микрофон.

# %%
6*. Прочитайте высказывания, установите их истинность и постройте противоположное высказывание:

a)∀x∈R∃X∈R:X>x
    Для любого x принадлежащего множеству действительных чисел, 
    найдётся такой элемент X принадлежащий множеству действительных чисел, 
    что он будет больше x.
б)∀y∈[0;π2]∃ε>0:siny<sin(y+ε)
    Для любого y лежащего на промежутке [0;π2] включая крайние точки,
    есть такой положительный ε, что siny<sin(y+ε)
    Утверждение не верно
в)∀y∈[0;π)∃ε>0:cosy>cos(y+ε)
      Для любого y лежащего на промежутке [0;π) не включая правую точку,
      есть такой положительный ε, что cosy>cos(y+ε)
