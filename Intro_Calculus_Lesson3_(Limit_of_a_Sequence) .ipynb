# %%
1. Найти предел последовательности:

а)limn→∞(23−2n2)(3n2+17)24n6+n−1 
б)limn→∞(97−2n)32n(3n2+15)+8n 
в)limn→∞2n3+13n(n+18)(27−n)(2n+19)2 
г)limn→∞(n2+1−−−−−√−n) 
д)limn→∞(−4)n+5⋅7n(−4)n−1+7n+2 
e)∗limn→∞(11⋅2+12⋅3+13⋅4+...+1(n−1)⋅n) 

2. Представьте 1 в виде суммы трех обыкновенных дробей с разными знаменателями и числителем равным 1.

3∗. Тоже задание, только в виде суммы шести дробей.

4. Пользуясь критерием Коши, докажите сходимость последовательности:

an=sin12+sin222+sin323+..sinn2n⇒
{an}∞n=1={sin12,sin12+sin222,...,an,...}
∗ Какой член последовательности можно взять в качестве предела с точностью ε=10−7?

5∗. Пользуясь критерием Коши, докажите расходимость последовательности:

bn=1+12+13+..1n⇒
{bn}∞n=1={1,1+12,1+12+13,...,bn,...}

# %%
1. Найти предел последовательности:

а)limn→∞(23−2n2)(3n2+17)24n6+n−1 
-18/4 = -9/2 степень числителя 6, знаменателя 6

б)limn→∞(97−2n)32n(3n2+15)+8n 
-4/3 = 1 и 1/3 степень числителя 3, степень знаменателя 3

в)limn→∞2n3+13n(n+18)(27−n)(2n+19)2 
-1/2 степень числителя 2, степень знаменателя 3

г)limn→∞(n2+1−−−−−√−n) 
0, в ответе 1/∞

д)limn→∞(−4)n+5⋅7n(−4)n−1+7n+2 
5/49 

e)∗limn→∞(11⋅2+12⋅3+13⋅4+...+1(n−1)⋅n) 
?????

# %%
2. Представьте 1 в виде суммы трех обыкновенных дробей с разными знаменателями и числителем равным 1.

1 = 1/2 + 1/3 + 1/6

# %%
3∗. Представьте 1 в виде суммы шести дробей с разными знаменателями и числителем равным 1.

1 = 1/2 + 1/3 + 1/6 + 1/12 + 1/18 + 1/36

# %%
4. Пользуясь критерием Коши, докажите сходимость последовательности:
an=sin12+sin222+sin323+..sinn2n⇒
{an}∞n=1={sin12,sin12+sin222,...,an,...}
∗ Какой член последовательности можно взять в качестве предела с точностью ε=10−7?

# %%
5∗. Пользуясь критерием Коши, докажите расходимость последовательности:
bn=1+12+13+..1n⇒
{bn}∞n=1={1,1+12,1+12+13,...,bn,...}
|a(n+k)-a(k)| = 1/(n+1)+ ..+1/(n+k) > k/(n+k) k = n |xn + k - xn| > n/2n = 1/2 = ε
